# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
nfl_rushing = pd.read_csv("/Users/Troy Nally/OneDrive/Desktop/Code_Louisville/data_1_checks/assets/2021_player_rushing.csv")
print(nfl_rushing)
# Out:
#             Player  Rush Yds  Att  TD  20+  40+  Lng  Rush 1st  Rush 1st%  \
# 0  Jonathan Taylor      1811  332  18   14    5   83       107      3.103
# 1       Nick Chubb      1259  228   8   12    2   70        61      3.738
# 2        Joe Mixon      1205  292  13    6    0   32        60      4.867
# 3     Najee Harris      1200  307   7    6    0   37        62      4.952
# 4      Dalvin Cook      1159  249   6    9    1   66        57      4.368
# 5   Antonio Gibson      1037  258   7    4    0   27        65      3.969
# 6  Ezekiel Elliott      1002  237  10    3    1   47        55      4.309
# 7  Elijah Mitchell       963  207   5    6    0   39        47      4.404
# 8    Derrick Henry       937  219  10    3    2   76        49      4.469
# 9    Damien Harris       929  202  15    8    1   64        55      3.673
#
#    Rush FUM
# 0         3
# 1         2
# 2         1
# 3         0
# 4         3
# 5         5
# 6         1
# 7         0
# 8         1
# 9         2

# %%
plt.figure(figsize = (20, 10))
plt.scatter(nfl_rushing['Player'], nfl_rushing['Rush Yds'], color = 'blue')
plt.title('Top 10 2021 NFL Rushing Leaders', fontsize=25)
plt.xlabel('NFL Player', fontsize=15)
plt.ylabel('Rushing Yards', fontsize=15)
plt.show()
