# %%
# Use Python's requests library to scrape data from the NFL's website

pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Issue a GET request to retrieve the HTML data and store in Jupyter Notebook

import requests

URL = 'https://www.nfl.com/stats/team-stats/'
page = requests.get(URL)

print(page.text)
# Out:
# <!DOCTYPE html><html lang="en-US" dir="ltr"><head><meta charset="utf-8"><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"><meta name="viewport" content="width=device-width, initial-scale=1.0"><link rel="canonical" href="https://www.nfl.com/stats/team-stats/"><link rel="dns-prefetch" href="//nflenterprises.tt.omtrdc.net"><link rel="preconnect" href="//securepubads.g.doubleclick.net"><link rel="preconnect" href="//cdn.onesignal.com"><link rel="preconnect" href="//assets.adobedtm.com"><script async>(function(){var host=window.location.hostname;var element=document.createElement('script');var firstScript=document.getElementsByTagName('script')[0];var url='https://quantcast.mgr.consensu.org'.concat('/choice/','gGpYeVwuEvd4w','/',host,'/choice.js')
# ...

# %%
# Use Python library Beautiful Soup to parse the data

pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Create a Beautiful Soup object to take the scraped data as its input to be parsed

import requests

from bs4 import BeautifulSoup

URL = 'https://www.nfl.com/stats/team-stats/'
page = requests.get(URL)

soup = BeautifulSoup(page.content, 'html.parser')
